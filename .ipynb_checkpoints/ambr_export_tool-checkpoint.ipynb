# %% [markdown]
# # ambr250 Data Export
#
# This is a tool to reformat ambr250 data into an EDD-importable format.

# %% [markdown]
# # 1. Specify name of project
#
# Enter the name of the ambr250 data folder name below.
#
# Ex: For a folder with the name FCIC_AMBR_05 enter 'FCIC_AMBR_05' as the project_name variable.

# %%
project_name = 'FCIC_AMBR_05'

# %%
data_directory = project_name + '/Data/00001/B/'
export_params_file = 'export_parameters.txt'
library_file = "param_library.json"
datetime_format = "%Y-%m-%dT%H:%M:%S.%f"

# %% [markdown]
# # 2. Pick export parameters
#
# Pick your desired export parameters and enter them into export_parameters.txt. A complete list of parameters can be found below:

# %%
with open(library_file) as param_library:
    param_patterns = json.load(param_library)
sorted_params = sorted([param for param in param_patterns])
for param in sorted_params:
    print(param)
# Out:
# (1 per Total dry gas flow) (smoothed) (min per mL)
# 06a17834-55e3-453d-9642-69e05b5031d8.IsEnabled_SP
# 1f6daeba-0d4a-4cb9-bbfd-36f23e5ea028.ActiveLoopIndex
# 1f6daeba-0d4a-4cb9-bbfd-36f23e5ea028.ActiveLoopStringKey
# 1f6daeba-0d4a-4cb9-bbfd-36f23e5ea028.IntegralError
# 1f6daeba-0d4a-4cb9-bbfd-36f23e5ea028.IsEnabled_SP
# 1f6daeba-0d4a-4cb9-bbfd-36f23e5ea028.LastDifferentialError
# 1f6daeba-0d4a-4cb9-bbfd-36f23e5ea028.LastError
# 1f6daeba-0d4a-4cb9-bbfd-36f23e5ea028.LastError (raw)
# 5ceb56a6-95dd-4582-a154-1bfa70fb7a49_SP
# Acid flow rate (mL per h)
# Acid flow rate (raw) (mL per h)
# Acid flow rate multiplier_SP
# Acid flow rate_SP (mL per h)
# Acid reference volume pumped (mL)
# Acid volume pumped (mL)
# Acid volume since reset (mL)
# Acid volume since reset reference (mL)
# Air (headspace) added flow_SP (mL per min)
# Air (headspace) correction factor
# Air (headspace) flow (mL per min)
# Air (headspace) flow_SP (mL per min)
# Air (headspace) mix_SP (%)
# Air (headspace) primary flow_SP (mL per min)
# Air (headspace) valve open (%)
# Air (headspace) valve open_SP (%)
# Air (headspace) volume (L)
# Air added flow_SP (mL per min)
# Air correction factor
# Air flow (mL per min)
# Air flow_SP (mL per min)
# Air mix_SP (%)
# Air primary flow_SP (mL per min)
# Air valve open (%)
# Air valve open_SP (%)
# Air volume (L)
# Antifoam flow rate (mL per h)
# Antifoam flow rate (raw) (mL per h)
# Antifoam flow rate multiplier_SP
# Antifoam flow rate_SP (mL per h)
# Antifoam reference volume pumped (mL)
# Antifoam volume pumped (mL)
# Antifoam volume since reset (mL)
# Antifoam volume since reset reference (mL)
# Audit
# Base flow rate (mL per h)
# Base flow rate (raw) (mL per h)
# Base flow rate multiplier_SP
# Base flow rate_SP (mL per h)
# Base volume pumped (mL)
# Base volume since reset (mL)
# Bioreactor pressure reading (mbar)
# Bioreactors left to inoculate (bioreactors)
# Block temperature ( deg C)
# Block temperature_SP ( deg C)
# CER (mmol per L per h)
# CER (simple) (mmol per L per h)
# CER - raw, unnormalized (mmol per h)
# CER - raw, unnormalized (simple) (mmol per h)
# CER - unnormalized (mmol per h)
# CER - unnormalized (simple) (mmol per h)
# CO2 (headspace) added flow_SP (mL per min)
# CO2 (headspace) correction factor
# CO2 (headspace) flow (mL per min)
# CO2 (headspace) flow_SP (mL per min)
# CO2 (headspace) mix_SP (%)
# CO2 (headspace) primary flow_SP (mL per min)
# CO2 (headspace) valve open (%)
# CO2 (headspace) valve open_SP (%)
# CO2 (headspace) volume (L)
# CO2 added flow_SP (mL per min)
# CO2 correction factor
# CO2 flow (mL per min)
# CO2 flow_SP (mL per min)
# CO2 interpretation pressure (mbar)
# CO2 interpretation pressure_SP (mbar)
# CO2 mix_SP (%)
# CO2 primary flow_SP (mL per min)
# CO2 valve open (%)
# CO2 valve open_SP (%)
# CO2 volume (L)
# Cap off
# Checked by liquid handler
# Chiller (%)
# Chiller_SP (%)
# Clamp plate chiller (%)
# Clamp plate heater (%)
# Clamp plate temperature ( deg C)
# Clamp plate temperature_SP ( deg C)
# DO (% air sat.)
# DO before offset (% air sat.)
# DO spot (% air sat.)
# DO spot air saturation (upper O2 point) (% air sat.)
# DO spot amplitude (Amplitude)
# DO spot calibration 0% phase (Phase)
# DO spot calibration 0% temperature ( deg C)
# DO spot calibration 100% phase (Phase)
# DO spot calibration 100% temperature ( deg C)
# DO spot phase (Phase)
# DO spot reader enabled_SP
# DO_SP (% air sat.)
# Evaluation counter
# Export enabled_SP
# Feed#1 flow rate (mL per h)
# Feed#1 flow rate (raw) (mL per h)
# Feed#1 flow rate multiplier_SP
# Feed#1 flow rate_SP (mL per h)
# Feed#1 reference volume pumped (mL)
# Feed#1 volume pumped (mL)
# Feed#1 volume since reset (mL)
# Feed#1 volume since reset reference (mL)
# Feed#2 flow rate (mL per h)
# Feed#2 flow rate (raw) (mL per h)
# Feed#2 flow rate multiplier_SP
# Feed#2 flow rate_SP (mL per h)
# Feed#2 reference volume pumped (mL)
# Feed#2 volume pumped (mL)
# Feed#2 volume since reset (mL)
# Feed#2 volume since reset reference (mL)
# Feed#3 flow rate (mL per h)
# Feed#3 flow rate (raw) (mL per h)
# Feed#3 flow rate multiplier_SP
# Feed#3 flow rate_SP (mL per h)
# Feed#3 reference volume pumped (mL)
# Feed#3 volume pumped (mL)
# Feed#3 volume since reset (mL)
# Feed#3 volume since reset reference (mL)
# Feed#4 flow rate (mL per h)
# Feed#4 flow rate (raw) (mL per h)
# Feed#4 flow rate multiplier_SP
# Feed#4 flow rate_SP (mL per h)
# Feed#4 reference volume pumped (mL)
# Feed#4 volume pumped (mL)
# Feed#4 volume since reset (mL)
# Feed#4 volume since reset reference (mL)
# Foam sensor (a-to-d count)
# Foam sensor dark reading (a-to-d count)
# Foam sensor enabled_SP
# Foam sensor light reading (a-to-d count)
# Gas composition measured (%)
# Gas set
# Gas throttle ratio
# Heater (%)
# Heater_SP (%)
# Inlet H2O% (%)
# Inlet O2% (%)
# Inlet O2% (smoothed and lagged) (%)
# Inlet O2% (smoothed) (%)
# Lights - light on
# Lights - reactor selected
# Liquid handling
# Liquid handling transfers
# Mass flow sensor zero gas flow reading (mL per min)
# Mass loss (g)
# N2 (headspace) added flow_SP (mL per min)
# N2 (headspace) correction factor
# N2 (headspace) flow (mL per min)
# N2 (headspace) flow_SP (mL per min)
# N2 (headspace) mix_SP (%)
# N2 (headspace) primary flow_SP (mL per min)
# N2 (headspace) valve open (%)
# N2 (headspace) valve open_SP (%)
# N2 (headspace) volume (L)
# N2 added flow_SP (mL per min)
# N2 correction factor
# N2 flow (mL per min)
# N2 flow_SP (mL per min)
# N2 mix_SP (%)
# N2 primary flow_SP (mL per min)
# N2 valve open (%)
# N2 valve open_SP (%)
# N2 volume (L)
# Normalisation volume (mL)
# O2 (headspace) added flow_SP (mL per min)
# O2 (headspace) correction factor
# O2 (headspace) flow (mL per min)
# O2 (headspace) flow_SP (mL per min)
# O2 (headspace) mix_SP (%)
# O2 (headspace) primary flow_SP (mL per min)
# O2 (headspace) valve open (%)
# O2 (headspace) valve open_SP (%)
# O2 (headspace) volume (L)
# O2 added flow_SP (mL per min)
# O2 correction factor
# O2 flow (mL per min)
# O2 flow_SP (mL per min)
# O2 mix_SP (%)
# O2 primary flow_SP (mL per min)
# O2 valve open (%)
# O2 valve open_SP (%)
# O2 volume (L)
# OUR (mmol per L per h)
# OUR (simple) (mmol per L per h)
# OUR - raw, unnormalized (mmol per h)
# OUR - raw, unnormalized (simple) (mmol per h)
# OUR - unnormalized (mmol per h)
# OUR - unnormalized (simple) (mmol per h)
# OUR_SP (mmol per L per h)
# Off-gas CO2 active reading (a-to-d count)
# Off-gas CO2 active reading max (a-to-d count)
# Off-gas CO2 active reading min (a-to-d count)
# Off-gas CO2 reference reading (a-to-d count)
# Off-gas CO2 reference reading max (a-to-d count)
# Off-gas CO2 reference reading min (a-to-d count)
# Off-gas CO2 sensor temperature ( deg C)
# Off-gas CO2 thermistor reading (a-to-d count)
# Off-gas CO2% (%)
# Off-gas H2O% (%)
# Off-gas O2 low range reading (a-to-d count)
# Off-gas O2% (%)
# Off-gas O2% - raw expected zero OUR (%)
# Off-gas O2% net of humidity (%)
# Off-gas O2% raw from PCB (%)
# Off-gas calculations suppressed
# Off-gas lag time (s)
# Off-gas mixing time (s)
# Phase
# Pump A CIP remaining volume (mL)
# Pump A CIP start volume (mL)
# Pump A bolus volume SP (mL)
# Pump A commanded flow rate (mL per h)
# Pump A commanded refill rate (mL per h)
# Pump A commanded total volume (mL)
# Pump A flow rate (mL per h)
# Pump A flow rate (motor counts) (counts per h)
# Pump A flow rate (raw) (mL per h)
# Pump A flow rate multiplier_SP
# Pump A flow rate_SP (mL per h)
# Pump A internal flow rate multiplier_SP
# Pump A pulse flow off time_SP (s)
# Pump A pulse flow on time_SP (s)
# Pump A pulse flow rate (mL per h)
# Pump A pump command
# Pump A refill rate_SP (mL per h)
# Pump A respond to hardware interlock_SP
# Pump A stopped for change
# Pump A syringe percent full (%)
# Pump A syringe position (counts)
# Pump A total volume (mL)
# Pump A total volume (motor counts) (counts)
# Pump A total volume_SP (mL)
# Pump A volume relative to inlet (mL)
# Pump A volume since reset (mL)
# Pump B CIP remaining volume (mL)
# Pump B CIP start volume (mL)
# Pump B bolus volume SP (mL)
# Pump B commanded flow rate (mL per h)
# Pump B commanded refill rate (mL per h)
# Pump B commanded total volume (mL)
# Pump B fallback averaging time (s)
# Pump B flow rate (mL per h)
# Pump B flow rate (motor counts) (counts per h)
# Pump B flow rate (raw) (mL per h)
# Pump B flow rate multiplier_SP
# Pump B flow rate_SP (mL per h)
# Pump B internal flow rate multiplier_SP
# Pump B pulse flow off time_SP (s)
# Pump B pulse flow on time_SP (s)
# Pump B pulse flow rate (mL per h)
# Pump B pump command
# Pump B refill rate_SP (mL per h)
# Pump B respond to hardware interlock_SP
# Pump B stopped for change
# Pump B syringe percent full (%)
# Pump B syringe position (counts)
# Pump B total volume (mL)
# Pump B total volume (motor counts) (counts)
# Pump B total volume synced
# Pump B total volume_SP (mL)
# Pump B volume per step (mL)
# Pump B volume pumped (mL)
# Pump B volume relative to inlet (mL)
# Pump B volume since reset (mL)
# Pump C CIP remaining volume (mL)
# Pump C CIP start volume (mL)
# Pump C bolus volume SP (mL)
# Pump C commanded flow rate (mL per h)
# Pump C commanded refill rate (mL per h)
# Pump C commanded total volume (mL)
# Pump C flow rate (mL per h)
# Pump C flow rate (motor counts) (counts per h)
# Pump C flow rate (raw) (mL per h)
# Pump C flow rate multiplier_SP
# Pump C flow rate_SP (mL per h)
# Pump C internal flow rate multiplier_SP
# Pump C pulse flow off time_SP (s)
# Pump C pulse flow on time_SP (s)
# Pump C pulse flow rate (mL per h)
# Pump C pump command
# Pump C refill rate_SP (mL per h)
# Pump C respond to hardware interlock_SP
# Pump C stopped for change
# Pump C syringe percent full (%)
# Pump C syringe position (counts)
# Pump C total volume (mL)
# Pump C total volume (motor counts) (counts)
# Pump C total volume_SP (mL)
# Pump C volume relative to inlet (mL)
# Pump C volume since reset (mL)
# Pump D CIP remaining volume (mL)
# Pump D CIP start volume (mL)
# Pump D bolus volume SP (mL)
# Pump D commanded flow rate (mL per h)
# Pump D commanded refill rate (mL per h)
# Pump D commanded total volume (mL)
# Pump D flow rate (mL per h)
# Pump D flow rate (motor counts) (counts per h)
# Pump D flow rate (raw) (mL per h)
# Pump D flow rate multiplier_SP
# Pump D flow rate_SP (mL per h)
# Pump D internal flow rate multiplier_SP
# Pump D pulse flow off time_SP (s)
# Pump D pulse flow on time_SP (s)
# Pump D pulse flow rate (mL per h)
# Pump D pump command
# Pump D refill rate_SP (mL per h)
# Pump D respond to hardware interlock_SP
# Pump D stopped for change
# Pump D syringe percent full (%)
# Pump D syringe position (counts)
# Pump D total volume (mL)
# Pump D total volume (motor counts) (counts)
# Pump D total volume_SP (mL)
# Pump D volume relative to inlet (mL)
# Pump D volume since reset (mL)
# RQ
# Reference times
# Release gas pressure requested
# Sampling events
# State
# Step state counter
# Steps disabled
# Steps locked for editing
# Stir average power (W)
# Stir average speed (rpm)
# Stir direction
# Stir direction_SP
# Stir maximum power (W)
# Stir maximum speed (rpm)
# Stir minimum power (W)
# Stir minimum speed (rpm)
# Stir power standard deviation (W)
# Stir speed (rpm)
# Stir speed fallback averaging time (s)
# Stir speed standard deviation (rpm)
# Stir speed_SP (rpm)
# Temperature ( deg C)
# Temperature_SP ( deg C)
# Total N2 flow (mL per min)
# Total O2 flow (mL per min)
# Total dry gas flow (smoothed and lagged) (mL per min)
# Total dry gas flow (smoothed) (mL per min)
# Total gas flow (mL per min)
# Total gas volume (L)
# Total headspace gas flow (mL per min)
# Total headspace gas volume (L)
# Volume (mL)
# Volume - net water loss (mL)
# Volume - process pipetting (mL)
# Volume - sampled (mL)
# Volume pipetted - Antifoam solution (mL)
# Volume pipetted - Unknown (mL)
# _ClampPlateTemperatureHighAlarm.State
# _ClampPlateTemperatureLowAlarm.State
# aea419f2-5c98-4ffe-a487-5f0bee24cffb.ActiveLoopIndex
# aea419f2-5c98-4ffe-a487-5f0bee24cffb.ActiveLoopStringKey
# aea419f2-5c98-4ffe-a487-5f0bee24cffb.IntegralError
# aea419f2-5c98-4ffe-a487-5f0bee24cffb.IsEnabled_SP
# aea419f2-5c98-4ffe-a487-5f0bee24cffb.LastDifferentialError
# aea419f2-5c98-4ffe-a487-5f0bee24cffb.LastError
# aea419f2-5c98-4ffe-a487-5f0bee24cffb.LastError (raw)
# eb55980f-9532-4dd1-9520-16301f4e4293.IsEnabled_SP
# pH (pH)
# pH before offset (pH)
# pH.Probe (pH)
# pH.Probe.Temperature ( deg C)
# pH.Probe.mV (mV)
# pH_SP_(Lower) (pH)
# pH_SP_Upper (pH)

# %% [markdown]
# # 3. Generate EDD Import Files
#
# Go to Cell > Run All to generate the EDD import files for the chosen parameters.

# %%
import pandas as pd
import numpy as np
import os
import re
import json
import datetime

# %%
def write_to_csv(filename, patterns, earliest_time_in_microseconds):
    '''
    Converts input .csv files into pandas dataframe, selects for export parameters
    and writes as compiled .csv file.
    
    string filename: filepath to bioreactor (HT1-HT12) that is being exported
    dictionary patterns: dictionary with pattern names and their corresponding regex patterns
    '''
    reactor_data = os.path.join(data_directory, filename)
    worksheet_name = 'HT' + str(int(filename))
    compiled = pd.DataFrame({'' : []})
    # Iterate through export parameters
    for parameter in open(export_params_file):
        # Get pattern for export parameter from library
        pattern = patterns[parameter.rstrip('\n')]
        # Iterate through .csv files and check for pattern match
        for sheet_name in os.listdir(reactor_data):
            if re.match(pattern, sheet_name):
                sheet_path = os.path.join(reactor_data, sheet_name)
                df = pd.read_csv(sheet_path, usecols=[0,1], header=2)
                # Reformat column header
                df.rename(columns={"VariableKey": "Time"}, inplace=True)
                # Assign compiled dataframe or concatenate to existing dataframe
                reformatted_data = {}
                unit = re.findall('\(([^)]+)\)', sheet_name)
                line_name = project_name + "_" + worksheet_name
                times = df["Time"].values.tolist()
                earliest_time = datetime.datetime.strptime(earliest_time_in_microseconds, datetime_format)
                
                time_differences = []
                for time in times:
                    time_datetime = datetime.datetime.strptime(time[:-1], datetime_format)
                    difference = time_datetime - earliest_time
                    time_differences.append(difference.total_seconds())
                                
                reformatted_data["Line Name"] = [line_name for _ in df["Time"]]
                reformatted_data["Measurement Type"] = [parameter.rstrip() for _ in df["Time"]]
                reformatted_data["Time"] = time_differences
                reformatted_data["Value"] = df.iloc[:,1]
                reformatted_data["Units"] = [unit[-1].strip() if unit else 'n/a' for _ in df["Time"]]
                
                order = ["Line Name", "Measurement Type", "Time", "Value", "Units"]
                reformatted_df = pd.DataFrame(data=reformatted_data)
                reformatted_df = reformatted_df[order].dropna()
                

                # Export completed dataframe as .csv file
                export_filename = project_name + "_" + worksheet_name + "_" + parameter.rstrip() + ".csv"
                reformatted_df.to_csv(export_filename, index=False)  
            
def compile_bioreactors(directory):
    '''
    Iterates through HT1-HT12 and calls export function
    
    string directory: filepath to directory containing HT1-HT12 data.
    '''
    earliest_time_in_microseconds = find_earliest_time(data_directory)[:-1]
    with open(library_file) as param_library:
        # Load parameter pattern library
        param_patterns = json.load(param_library)
    for filename in os.listdir(directory):
            # Match for bioreactor name (HT1-HT12)
            if re.match('\d{2}', filename):
                write_to_csv(filename, param_patterns, earliest_time_in_microseconds)
    print("All data exported.")

def find_earliest_time(directory):
    times = []
    reactor_data = os.path.join(data_directory, '01')
    for sheet_name in os.listdir(reactor_data):
        sheet_path = os.path.join(reactor_data, sheet_name)
        df = pd.read_csv(sheet_path, usecols=[0,1], header=2)
        times.append(df.iloc[0][0])
    return min(times)

# %%
compile_bioreactors(data_directory)
# Out:
# All data exported.
